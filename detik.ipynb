# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv
from urllib.parse import urljoin

# %%
def scrape_detik(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        # Ambil konten halaman
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Cari elemen yang mengandung judul berita
        title = soup.find('h1', {'class': 'detail__title'})
        if title:
            title = title.get_text(strip=True)
        else:
            title = "Judul tidak ditemukan"
        
        # Cari elemen yang mengandung isi berita
        content_div = soup.find('div', {'class': 'detail__body-text'})
        if content_div:
            paragraphs = content_div.find_all('p')
            content = '\n'.join([p.get_text(strip=True) for p in paragraphs])
        else:
            content = "Konten tidak ditemukan"
        
        return {
            'title': title,
            'content': content,
            'url': url
        }
        
    except Exception as e:
        print(f"Error saat scraping {url}: {str(e)}")
        return None

# %%
def main():
    # URL target (bisa diganti dengan URL berita spesifik)
    base_url = "https://news.detik.com/berita"
    
    # Daftar URL berita yang akan di-scrape (contoh mengambil beberapa berita terbaru)
    news_urls = []
    
    # Ambil daftar berita dari halaman utama
    try:
        response = requests.get(base_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        articles = soup.find_all('article')
        
        for article in articles:
            link = article.find('a')['href']
            full_url = urljoin(base_url, link)
            news_urls.append(full_url)
    except Exception as e:
        print(f"Error mendapatkan daftar berita: {str(e)}")
    
    # Scrape setiap berita
    news_data = []
    for url in news_urls:
        print(f"Memproses: {url}")
        data = scrape_detik(url)
        if data:
            news_data.append(data)
    
    # Simpan ke CSV
    if news_data:
        df = pd.DataFrame(news_data)
        df.to_csv('detik_berita.csv', index=False, quoting=csv.QUOTE_ALL, encoding='utf-8-sig')
        print("Data berhasil disimpan")
    else:
        print("Tidak ada data yang berhasil di-scrape")

if __name__ == "__main__":
    main()
# Out:
# Memproses: https://news.detik.com/berita/d-8043532/geger-penumpang-lion-air-marah-marah-dan-teriak-ada-bom
# Memproses: https://news.detik.com/internasional/d-8043515/menteri-israel-pimpin-ibadah-yahudi-di-masjid-al-aqsa-turki-meradang
# Memproses: https://news.detik.com/berita/d-8043525/6-fakta-pesawat-latih-jatuh-di-bogor-marsma-fajar-adriyanto-gugur
# Memproses: https://news.detik.com/berita/d-8043609/ganjar-ungkap-alasan-hasto-tak-ada-di-susunan-kepengurusan-pdip
# Memproses: https://news.detik.com/berita/d-8043543/ulah-wanita-tenteng-tas-hermes-malah-curi-berlian-di-mal
# Memproses: https://news.detik.com/berita/d-8044410/lahan-di-cariu-bogor-terbakar-dipicu-warga-bakar-rumput
# Memproses: https://news.detik.com/berita/d-8044344/pria-ngamuk-teriak-bom-di-pesawat-lion-air-sempat-dirawat-di-rsj
# Memproses: https://news.detik.com/berita/d-8044325/hujan-deras-disertai-angin-kencang-terjang-tangsel
# Memproses: https://news.detik.com/berita/d-8044397/polda-jateng-pasok-semen-perbaiki-jembatan-akses-ke-sawah-di-banjarnegara
# Memproses: https://news.detik.com/berita/d-8044390/pemprov-dorong-18-kabupaten-kota-di-jabar-olah-sampah-dengan-fasilitas-rdf
# Memproses: https://news.detik.com/berita/d-8044384/benyamin-davnie-tinawati-andra-soni-hadiri-panen-anggur-lokal-di-tangsel
# Memproses: https://news.detik.com/berita/d-8044370/brimob-polda-metro-bagikan-5-000-bendera-merah-putih-sambut-hut-ri
# Memproses: https://news.detik.com/berita/d-8044366/aksi-polda-jateng-salurkan-1-ton-beras-dalam-gerakan-pangan-murah
# Memproses: https://news.detik.com/berita/d-8044344/pria-ngamuk-teriak-bom-di-pesawat-lion-air-sempat-dirawat-di-rsj
# Memproses: https://news.detik.com/berita/d-8044327/kejagung-segera-kembalikan-macbook-ipad-tom-lembong-usai-bebas
# Memproses: https://news.detik.com/berita/d-8044325/hujan-deras-disertai-angin-kencang-terjang-tangsel
# Memproses: https://news.detik.com/berita/d-8044308/mensos-buka-mpls-sekolah-rakyat-di-ponorogo-puji-dukungan-kepala-daerah
# Memproses: https://news.detik.com/berita/d-8044298/yusril-minta-percepat-layanan-digital-imipas-hindari-belanja-tak-mendukung
# Memproses: https://news.detik.com/berita/d-8044291/bahlil-tegaskan-tak-ada-munaslub-golkar
# Memproses: https://news.detik.com/berita/d-8044289/tom-lembong-laporkan-hakim-pemvonis-4-5-tahun-bui-ke-ma-harap-ada-evaluasi
# Memproses: https://news.detik.com/berita/d-8044282/polantas-menyapa-polisi-bagikan-bendera-merah-putih-ke-pengendara
# Memproses: https://news.detik.com/berita/d-8044209/menimbang-makna-pdip-sebagai-penyeimbang
# Memproses: https://news.detik.com/berita/d-8044277/istana-soal-hasto-tom-lembong-2-kasus-ini-nuansanya-lebih-masalah-politik
# Memproses: https://news.detik.com/berita/d-8044275/pramono-perbolehkan-warga-luar-jakarta-daftar-jadi-petugas-damkar-dki
# Memproses: https://news.detik.com/berita/d-8044259/pihak-sewakan-hotel-untuk-eks-sekretaris-ma-windy-idol-kembali-dipanggil-kpk
# Memproses: https://news.detik.com/berita/d-8044254/geng-pelajar-penyiram-air-keras-ke-siswa-smk-di-jakut-juga-rampas-motor
# Memproses: https://news.detik.com/berita/d-8044230/eks-ketua-dprd-dki-prasetyo-edi-jabat-ketua-dewas-pam-jaya
# Memproses: https://news.detik.com/berita/d-8044222/menaker-yakin-project-based-learning-cetak-talenta-digital-siap-kerja
# Memproses: https://news.detik.com/berita/d-8044218/4-siswa-siram-air-keras-ke-pelajar-smk-di-jakut-jadi-tersangka
# Memproses: https://news.detik.com/berita/d-8044210/viral-pemotor-santai-melaju-di-tol-japek-ngaku-gegara-google-maps
# Memproses: https://news.detik.com/berita/d-8044207/soal-bendera-one-piece-prasetyo-harap-kesakralan-hut-ri-tak-terganggu
# Memproses: https://news.detik.com/berita/d-8044202/potret-penumpang-teriak-bom-di-pesawat-lion-air-kini-berbaju-tahanan
# Memproses: https://news.detik.com/berita/d-8044193/marsma-fajar-adriyanto-dimakamkan-di-samping-pusara-ayah-di-tpu-probolinggo
# Memproses: https://news.detik.com/berita/d-8044190/pohon-tumbang-di-depan-stasiun-cilebut-bogor-sempat-tutup-jalan
# Memproses: https://news.detik.com/berita/d-8044178/hasto-kristiyanto-jadi-satu-satunya-tahanan-kpk-dapat-amnesti-dari-prabowo
# Memproses: https://news.detik.com/berita/d-8044160/ketua-kpk-jawab-mega-soal-hasto-status-bersalah-melekat-tapi-diampuni
# Memproses: https://news.detik.com/berita/d-8044157/sambil-terisak-eks-ketua-pn-surabaya-minta-maaf-ke-ma-terjerat-kasus-suap
# Memproses: https://news.detik.com/berita/d-8044141/kebakaran-ruko-di-mangga-dua-landa-lantai-4-dan-5-kerugian-rp-20-m
# Memproses: https://news.detik.com/berita/d-8044137/gbn-2025-strategi-kemenperin-wujudkan-industri-batik-berkelanjutan
# Memproses: https://news.detik.com/berita/d-8044136/pria-ngamuk-teriak-bom-di-pesawat-lion-air-ditetapkan-jadi-tersangka
# Memproses: https://news.detik.com/berita/d-8044134/warga-tolak-tpa-bangkonol-tampung-sampah-tangsel-sekarang-bau-luar-biasa
# Memproses: https://news.detik.com/berita/d-8044122/mensesneg-ungkap-belum-ada-pembicaraan-kursi-menteri-untuk-pdip
# Memproses: https://news.detik.com/berita/d-8044121/polisi-ketua-ormas-di-sumut-kendalikan-pabrik-ekstasi
# Memproses: https://news.detik.com/berita/d-8044119/kepala-bpjph-gubernur-lampung-dukung-pelaksanaan-sertifikasi-halal-bagi-umk
# Memproses: https://news.detik.com/berita/d-8044117/kebakaran-ruko-mangga-dua-dipicu-korsleting-sempat-ada-ledakan
# Memproses: https://news.detik.com/berita/d-8044114/bareskrim-polri-mulai-usut-kasus-tambang-ilegal-di-kalimantan-tengah
# Memproses: https://news.detik.com/berita/d-8044100/sahabat-baik-bantu-kehidupan-sehari-hari-pak-ratmin-saat-pesanan-jahit-sepi
# Memproses: https://news.detik.com/berita/d-8044088/antisipasi-gangguan-kamtibmas-polda-banten-bentuk-tim-patroli-maung-presisi
# Memproses: https://news.detik.com/berita/d-8044086/pengacara-ungkap-rk-akan-tes-dna-pada-7-agustus-terkait-lisa-mariana
# Memproses: https://news.detik.com/berita/d-8044057/pimpinan-dpr-minta-kemenkum-tak-bikin-aturan-menyulitkan-soal-hak-cipta
# Memproses: https://news.detik.com/berita/d-8044046/sopir-mobil-curian-tanpa-ban-di-bogor-sempat-ditemukan-terluka
# Memproses: https://news.detik.com/berita/d-8044039/dewan-pakar-putuskan-21-finalis-adhyaksa-awards-2025-ini-daftarnya
# Memproses: https://news.detik.com/berita/d-8044037/menteri-imipas-buka-peluang-gandeng-tni-polri-jaga-lapas-rawan-narkoba
# Memproses: https://news.detik.com/berita/d-8044033/kantor-nyaru-jadi-pabrik-ekstasi-ketua-ormas-di-sumut-tewas-terjun-ke-sungai
# Memproses: https://news.detik.com/berita/d-8044030/pegawai-bandara-lombok-tewas-dibunuh-suami-diduga-dipicu-perselingkuhan
# Memproses: https://news.detik.com/berita/d-8044008/dasco-yakin-sugiono-tetap-menlu-usai-resmi-jadi-sekjen-gerindra
# Memproses: https://news.detik.com/berita/d-8044006/dasco-sampaikan-pesan-prabowo-saat-bertemu-megawati-puan-ini-isinya
# Memproses: https://news.detik.com/berita/d-8044001/soal-bendera-one-piece-eddy-soeparno-merah-putih-tetap-yang-tertinggi
# Memproses: https://www.detik.com/tag/hut-ri
# Memproses: https://www.detik.com/tag/kecelakaan-pesawat
# Memproses: https://www.detik.com/tag/palestina
# Memproses: https://news.detik.com/berita/d-8044136/pria-ngamuk-teriak-bom-di-pesawat-lion-air-ditetapkan-jadi-tersangka
# Memproses: https://news.detik.com/berita/d-8044160/ketua-kpk-jawab-mega-soal-hasto-status-bersalah-melekat-tapi-diampuni
# Memproses: https://news.detik.com/internasional/d-8043990/kaget-lihat-sandera-kurus-kering-netanyahu-minta-bantuan-palang-merah
# Memproses: https://news.detik.com/berita/d-8044202/potret-penumpang-teriak-bom-di-pesawat-lion-air-kini-berbaju-tahanan
# Memproses: https://news.detik.com/bbc-world/d-8044031/gempar-suap-menteri-singapura-miliuner-ong-beng-seng-mengaku-bersalah
# Memproses: https://news.detik.com/berita/d-8039340/ini-pertimbangan-prabowo-beri-abolisi-ke-tom-lembong-dan-amnesti-untuk-hasto
# Memproses: https://news.detik.com/berita/d-8039289/prabowo-beri-abolisi-ke-tom-lembong-dan-amnesti-untuk-hasto
# Memproses: https://news.detik.com/berita/d-8032088/ribka-pdip-sebut-tanpa-kudatuli-tak-ada-presiden-tukang-kayu-ini-kata-projo
# Data berhasil disimpan

# %%
def main():
    # URL target (bisa diganti dengan URL berita spesifik)
    base_url = "https://news.detik.com/jabodetabek"
    
    # Daftar URL berita yang akan di-scrape (contoh mengambil beberapa berita terbaru)
    news_urls = []
    
    # Ambil daftar berita dari halaman utama
    try:
        response = requests.get(base_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        articles = soup.find_all('article')
        
        for article in articles:
            link = article.find('a')['href']
            full_url = urljoin(base_url, link)
            news_urls.append(full_url)
    except Exception as e:
        print(f"Error mendapatkan daftar berita: {str(e)}")
    
    # Scrape setiap berita
    news_data = []
    for url in news_urls:
        print(f"Memproses: {url}")
        data = scrape_detik(url)
        if data:
            news_data.append(data)
    
    # Simpan ke CSV
    if news_data:
        df = pd.DataFrame(news_data)
        df.to_csv('detik_jabodetabek.csv', index=False, quoting=csv.QUOTE_ALL, encoding='utf-8-sig')
        print("Data berhasil disimpan")
    else:
        print("Tidak ada data yang berhasil di-scrape")

if __name__ == "__main__":
    main()
# Out:
# Memproses: https://news.detik.com/berita/d-8044344/pria-ngamuk-teriak-bom-di-pesawat-lion-air-sempat-dirawat-di-rsj
# Memproses: https://news.detik.com/berita/d-8044325/hujan-deras-disertai-angin-kencang-terjang-tangsel
# Memproses: https://news.detik.com/berita/d-8044275/pramono-perbolehkan-warga-luar-jakarta-daftar-jadi-petugas-damkar-dki
# Memproses: https://news.detik.com/berita/d-8044325/hujan-deras-disertai-angin-kencang-terjang-tangsel
# Memproses: https://news.detik.com/berita/d-8044275/pramono-perbolehkan-warga-luar-jakarta-daftar-jadi-petugas-damkar-dki
# Memproses: https://news.detik.com/berita/d-8044230/eks-ketua-dprd-dki-prasetyo-edi-jabat-ketua-dewas-pam-jaya
# Memproses: https://news.detik.com/berita/d-8044218/4-siswa-siram-air-keras-ke-pelajar-smk-di-jakut-jadi-tersangka
# Memproses: https://news.detik.com/berita/d-8044210/viral-pemotor-santai-melaju-di-tol-japek-ngaku-gegara-google-maps
# Memproses: https://news.detik.com/berita/d-8044202/potret-penumpang-teriak-bom-di-pesawat-lion-air-kini-berbaju-tahanan
# Memproses: https://news.detik.com/berita/d-8044190/pohon-tumbang-di-depan-stasiun-cilebut-bogor-sempat-tutup-jalan
# Memproses: https://news.detik.com/berita/d-8044141/kebakaran-ruko-di-mangga-dua-landa-lantai-4-dan-5-kerugian-rp-20-m
# Memproses: https://news.detik.com/berita/d-8044136/pria-ngamuk-teriak-bom-di-pesawat-lion-air-ditetapkan-jadi-tersangka
# Memproses: https://news.detik.com/berita/d-8044117/kebakaran-ruko-mangga-dua-dipicu-korsleting-sempat-ada-ledakan
# Memproses: https://news.detik.com/berita/d-8044046/sopir-mobil-curian-tanpa-ban-di-bogor-sempat-ditemukan-terluka
# Memproses: https://news.detik.com/berita/d-8043994/pelajar-di-jakut-patungan-beli-air-keras-untuk-siram-wajah-siswa-smk
# Memproses: https://news.detik.com/berita/d-8043986/polda-sumut-gerebek-kantor-ormas-disulap-jadi-pabrik-ekstasi-di-medan
# Memproses: https://news.detik.com/berita/d-8043883/pelajar-siram-air-keras-ke-siswa-smk-jakut-pelaku-korban-tak-saling-kenal
# Memproses: https://news.detik.com/berita/d-8043855/mobil-curian-tanpa-ban-di-pemakaman-bogor-ternyata-milik-perusahaan
# Memproses: https://news.detik.com/berita/d-8043839/momen-dirut-kai-nunduk-minta-maaf-atas-anjloknya-ka-argo-bromo-anggrek
# Memproses: https://news.detik.com/berita/d-8043823/ruko-di-lantai-5-mangga-dua-kebakaran-12-mobil-damkar-meluncur
# Memproses: https://news.detik.com/berita/d-8043794/kronologi-pria-teriak-bom-bikin-ratusan-penumpang-lion-air-ganti-pesawat
# Memproses: https://news.detik.com/berita/d-8043745/dirut-food-station-tersangka-pramono-tunjuk-dirkeu-jadi-plt-dirut
# Memproses: https://news.detik.com/berita/d-8043725/gagal-nyalip-pengendara-motor-tewas-terlindas-truk-di-bogor
# Memproses: https://news.detik.com/berita/d-8043631/lalin-di-exit-tol-tegal-parang-tersendat-ini-penyebabnya
# Memproses: https://news.detik.com/berita/d-8043625/truk-terbalik-di-tol-sedyatmo-arah-tomang-petugas-evakuasi
# Memproses: https://news.detik.com/berita/d-8043599/titik-titik-kepadatan-lalin-di-jalan-arteri-jakarta-pagi-ini
# Memproses: https://news.detik.com/berita/d-8043546/info-lalin-tol-arah-jakarta-pagi-ini-cililitan-cawang-padat
# Memproses: https://news.detik.com/berita/d-8043543/ulah-wanita-tenteng-tas-hermes-malah-curi-berlian-di-mal
# Memproses: https://news.detik.com/berita/d-8043525/6-fakta-pesawat-latih-jatuh-di-bogor-marsma-fajar-adriyanto-gugur
# Memproses: https://news.detik.com/berita/d-8043401/siswa-smk-di-tanjung-priok-disiram-air-keras-pelaku-sesama-pelajar
# Memproses: https://news.detik.com/berita/d-8043246/mayat-pria-tanpa-identitas-ditemukan-mengambang-di-kali-pik-jakut
# Memproses: https://news.detik.com/berita/d-8042973/warga-usul-pelebaran-jalan-dan-lampu-merah-atasi-macet-di-cinere-depok
# Memproses: https://news.detik.com/berita/d-8042868/brimob-polda-metro-bantu-amankan-aksi-bela-palestina-pastikan-kondusif
# Memproses: https://news.detik.com/berita/d-8042820/dalih-gaya-hidup-jadi-alasan-wanita-tenteng-hermes-curi-berlian-di-mal-jakut
# Memproses: https://news.detik.com/berita/d-8042810/sempat-disidak-walkot-ini-titik-biang-kerok-macet-di-cinere-depok
# Memproses: https://news.detik.com/berita/d-8042616/wanita-tenteng-tas-hermes-pindah-ke-apartemen-usai-curi-berlian-di-mal-jakut
# Memproses: https://news.detik.com/berita/d-8042593/toko-miras-berkedok-warung-kelontong-di-jonggol-dirazia-polisi
# Memproses: https://news.detik.com/berita/d-8042534/wanita-tenteng-tas-hermes-curi-liontin-di-toko-berlian-jakut
# Memproses: https://news.detik.com/berita/d-8042499/polisi-tangkap-7-mata-elang-di-depok-4-motor-disita
# Memproses: https://news.detik.com/berita/d-8042436/alasan-mega-soal-pdip-ambil-posisi-penyeimbang-pemerintah
# Memproses: https://news.detik.com/berita/d-8042413/2-123-personel-gabungan-amankan-aksi-damai-bela-palestina-di-monas
# Memproses: https://news.detik.com/berita/d-8042407/akhir-polemik-runyam-hunian-warga-kampung-bayam
# Memproses: https://news.detik.com/berita/d-8042336/sambut-hut-ke-80-ri-polres-tangsel-gelar-pelayanan-sim-kesehatan-gratis
# Data berhasil disimpan

# %%
def main():
    # URL target (bisa diganti dengan URL berita spesifik)
    base_url = "https://news.detik.com/internasional"
    
    # Daftar URL berita yang akan di-scrape (contoh mengambil beberapa berita terbaru)
    news_urls = []
    
    # Ambil daftar berita dari halaman utama
    try:
        response = requests.get(base_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        articles = soup.find_all('article')
        
        for article in articles:
            link = article.find('a')['href']
            full_url = urljoin(base_url, link)
            news_urls.append(full_url)
    except Exception as e:
        print(f"Error mendapatkan daftar berita: {str(e)}")
    
    # Scrape setiap berita
    news_data = []
    for url in news_urls:
        print(f"Memproses: {url}")
        data = scrape_detik(url)
        if data:
            news_data.append(data)
    
    # Simpan ke CSV
    if news_data:
        df = pd.DataFrame(news_data)
        df.to_csv('detik_internasional.csv', index=False, quoting=csv.QUOTE_ALL, encoding='utf-8-sig')
        print("Data berhasil disimpan")
    else:
        print("Tidak ada data yang berhasil di-scrape")

if __name__ == "__main__":
    main()
# Out:
# Memproses: https://news.detik.com/berita/d-8043532/geger-penumpang-lion-air-marah-marah-dan-teriak-ada-bom
# Memproses: https://news.detik.com/internasional/d-8043515/menteri-israel-pimpin-ibadah-yahudi-di-masjid-al-aqsa-turki-meradang
# Memproses: https://news.detik.com/berita/d-8043525/6-fakta-pesawat-latih-jatuh-di-bogor-marsma-fajar-adriyanto-gugur
# Memproses: https://news.detik.com/berita/d-8043609/ganjar-ungkap-alasan-hasto-tak-ada-di-susunan-kepengurusan-pdip
# Memproses: https://news.detik.com/berita/d-8043543/ulah-wanita-tenteng-tas-hermes-malah-curi-berlian-di-mal
# Memproses: https://news.detik.com/internasional/d-8044318/dewan-keamanan-pbb-akan-gelar-sidang-darurat-bahas-sandera-di-gaza
# Memproses: https://news.detik.com/internasional/d-8043990/kaget-lihat-sandera-kurus-kering-netanyahu-minta-bantuan-palang-merah
# Memproses: https://news.detik.com/internasional/d-8043933/macron-kecam-hamas-soal-sandera-israel-kurus-kering-tak-manusiawi
# Memproses: https://news.detik.com/internasional/d-8044294/tragis-kapal-migran-tenggelam-di-lepas-pantai-yaman-68-orang-tewas
# Memproses: https://news.detik.com/internasional/d-8044212/ingin-baikan-dengan-korut-korsel-copot-speaker-propaganda-di-perbatasan
# Memproses: https://news.detik.com/internasional/d-8044177/horor-kereta-tabrak-bus-di-rusia-1-orang-tewas-11-terluka
# Memproses: https://news.detik.com/internasional/d-8044140/pertama-kali-filipina-india-patroli-bareng-di-laut-china-selatan
# Memproses: https://news.detik.com/bbc-world/d-8044031/gempar-suap-menteri-singapura-miliuner-ong-beng-seng-mengaku-bersalah
# Memproses: https://news.detik.com/internasional/d-8044029/warga-as-tewas-di-tepi-barat-keluarga-salahkan-pemukim-israel
# Memproses: https://news.detik.com/internasional/d-8043990/kaget-lihat-sandera-kurus-kering-netanyahu-minta-bantuan-palang-merah
# Memproses: https://news.detik.com/internasional/d-8043933/macron-kecam-hamas-soal-sandera-israel-kurus-kering-tak-manusiawi
# Memproses: https://news.detik.com/internasional/d-8043850/iran-bentuk-dewan-pertahanan-baru-buntut-perang-dengan-israel
# Memproses: https://news.detik.com/internasional/d-8043747/arab-saudi-kecam-menteri-israel-berdoa-di-al-aqsa-provokatif
# Memproses: https://news.detik.com/internasional/d-8043715/langka-beberapa-kota-di-australia-diselimuti-salju-tebal
# Memproses: https://news.detik.com/internasional/d-8043680/trump-kirim-utusan-ke-rusia-pekan-depan-jelang-berakhirnya-tenggat-waktu
# Memproses: https://news.detik.com/internasional/d-8043577/hamas-bakal-izinkan-israel-beri-bantuan-ke-tahanannya-ini-syaratnya
# Memproses: https://news.detik.com/internasional/d-8043515/menteri-israel-pimpin-ibadah-yahudi-di-masjid-al-aqsa-turki-meradang
# Memproses: https://news.detik.com/internasional/d-8043479/kerusuhan-di-penjara-meksiko-7-napi-tewas-11-terluka
# Memproses: https://news.detik.com/internasional/d-8043476/tuai-kecaman-menteri-keamanan-israel-pimpin-ibadah-yahudi-di-masjid-al-aqsa
# Memproses: https://news.detik.com/internasional/d-8043459/kapal-tenggelam-di-perairan-yaman-27-migran-tewas-ratusan-penumpang-hilang
# Memproses: https://news.detik.com/internasional/d-8043423/komplotan-bandit-bersenjata-culik-50-orang-di-nigeria
# Memproses: https://news.detik.com/internasional/d-8043387/pesawat-akrobatik-jatuh-di-mallorca-spanyol-pilot-dan-penumpang-hilang
# Memproses: https://news.detik.com/internasional/d-8043194/singapura-boring-perdana-menteri-bilang-iya-tapi-yang-lain-mau-kayak-kami
# Memproses: https://news.detik.com/internasional/d-8043137/wanita-selandia-baru-ditangkap-gegara-bawa-anak-di-dalam-koper
# Memproses: https://news.detik.com/internasional/d-8043086/arab-saudi-eksekusi-mati-8-orang-dalam-sehari-termasuk-pembunuh-ibu
# Memproses: https://news.detik.com/internasional/d-8042993/6-orang-tewas-akibat-kelaparan-di-gaza-dalam-24-jam
# Memproses: https://news.detik.com/dw/d-8042874/mampukah-pemilu-legislatif-pulihkan-demokrasi-di-suriah
# Memproses: https://news.detik.com/internasional/d-8042826/pendiri-wikileaks-dan-ribuan-warga-di-australia-demo-desak-setop-perang-gaza
# Memproses: https://news.detik.com/bbc-world/d-8042771/kesaksian-ngeri-penyintas-kekerasan-seksual-sekte-jesus-army-di-inggris
# Memproses: https://news.detik.com/internasional/d-8042609/gunung-dormant-450-tahun-di-rusia-meletus-4-hari-usai-gempa-dashyat
# Memproses: https://news.detik.com/internasional/d-8042557/trump-dikritik-usai-pecat-pejabat-statistik-gara-gara-data-tenaga-kerja
# Memproses: https://news.detik.com/internasional/d-8042513/hamas-tolak-lucuti-senjata-hingga-negara-palestina-terbentuk
# Memproses: https://news.detik.com/internasional/d-8042453/saat-jalur-udara-jadi-pilihan-utama-kirim-bantuan-ke-gaza
# Memproses: https://news.detik.com/internasional/d-8042390/patung-trump-terbakar-api-amarah-warga-brasil-gegara-tarif-tinggi
# Memproses: https://news.detik.com/internasional/d-8042385/serangan-ukraina-hantam-perusahaan-militer-hingga-gudang-drone-iran-di-rusia
# Memproses: https://news.detik.com/internasional/d-8042384/junta-myanmar-serang-tambang-rubi-yang-dikuasai-pemberontak-13-orang-tewas
# Memproses: https://news.detik.com/internasional/d-8042372/bertemu-utusan-as-di-tel-aviv-keluarga-sandera-minta-perang-israel-disetop
# Memproses: https://news.detik.com/internasional/d-8042153/kala-trump-dan-eks-presiden-rusia-saling-ancam-kerahkan-nuklir
# Memproses: https://news.detik.com/bbc-world/d-8042056/cerita-astronom-perempuan-pertama-inggris-tak-belajar-ipa-saat-smp
# Memproses: https://news.detik.com/bbc-world/d-8041998/nasib-pekerja-migran-di-singapura-hari-ini-dipuji-besok-dicap-penipu
# Memproses: https://news.detik.com/internasional/d-8041995/5-berita-terpopuler-internasional-hari-ini
# Memproses: https://news.detik.com/internasional/d-8041963/israel-bilang-perang-gaza-tak-akan-berhenti-kecuali-sandera-dibebaskan
# Memproses: https://news.detik.com/internasional/d-8041922/banjir-tanah-longsor-tewaskan-6-orang-di-thailand
# Memproses: https://news.detik.com/internasional/d-8041811/serangan-drone-ukraina-hantam-rusia-3-orang-tewas
# Memproses: https://news.detik.com/internasional/d-8041665/marah-tarif-50-warga-brasil-ramai-ramai-bakar-patung-trump
# Memproses: https://news.detik.com/internasional/d-8041621/pilu-kelaparan-di-gaza-italia-kirim-bantuan-dari-udara
# Memproses: https://news.detik.com/internasional/d-8041471/awal-mula-ribut-ribut-dengan-rusia-bikin-trump-kirim-kapal-selam-nuklir
# Memproses: https://news.detik.com/dw/d-8041411/prancis-bangun-penjara-supermaksimum-demi-tumpas-sindikat-narkoba
# Memproses: https://news.detik.com/internasional/d-8041365/trump-bilang-kerahkan-kapal-selam-nuklir-karena-ancaman-eks-presiden-rusia
# Memproses: https://news.detik.com/internasional/d-8041333/houthi-tembakkan-rudal-ke-israel-tapi-berhasil-dicegat
# Memproses: https://news.detik.com/internasional/d-8041317/ribut-dengan-eks-presiden-rusia-trump-kerahkan-2-kapal-selam-nuklir
# Memproses: https://news.detik.com/internasional/d-8041252/proyek-gede-gedean-era-trump-bikin-ballroom-rp-3-2-t-di-gedung-putih
# Memproses: https://news.detik.com/internasional/d-8040931/aksi-israel-bikin-krisis-di-gaza-di-luar-imajinasi
# Memproses: https://www.detik.com/tag/hut-ri
# Memproses: https://www.detik.com/tag/kecelakaan-pesawat
# Memproses: https://www.detik.com/tag/palestina
# Memproses: https://news.detik.com/berita/d-8044136/pria-ngamuk-teriak-bom-di-pesawat-lion-air-ditetapkan-jadi-tersangka
# Memproses: https://news.detik.com/berita/d-8044160/ketua-kpk-jawab-mega-soal-hasto-status-bersalah-melekat-tapi-diampuni
# Memproses: https://news.detik.com/internasional/d-8043990/kaget-lihat-sandera-kurus-kering-netanyahu-minta-bantuan-palang-merah
# Memproses: https://news.detik.com/berita/d-8044202/potret-penumpang-teriak-bom-di-pesawat-lion-air-kini-berbaju-tahanan
# Memproses: https://news.detik.com/bbc-world/d-8044031/gempar-suap-menteri-singapura-miliuner-ong-beng-seng-mengaku-bersalah
# Memproses: https://news.detik.com/berita/d-8039340/ini-pertimbangan-prabowo-beri-abolisi-ke-tom-lembong-dan-amnesti-untuk-hasto
# Memproses: https://news.detik.com/berita/d-8039289/prabowo-beri-abolisi-ke-tom-lembong-dan-amnesti-untuk-hasto
# Memproses: https://news.detik.com/berita/d-8032088/ribka-pdip-sebut-tanpa-kudatuli-tak-ada-presiden-tukang-kayu-ini-kata-projo
# Data berhasil disimpan

# %%
def main():
    # URL target (bisa diganti dengan URL berita spesifik)
    base_url = "https://news.detik.com/hukum"
    
    # Daftar URL berita yang akan di-scrape (contoh mengambil beberapa berita terbaru)
    news_urls = []
    
    # Ambil daftar berita dari halaman utama
    try:
        response = requests.get(base_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        articles = soup.find_all('article')
        
        for article in articles:
            link = article.find('a')['href']
            full_url = urljoin(base_url, link)
            news_urls.append(full_url)
    except Exception as e:
        print(f"Error mendapatkan daftar berita: {str(e)}")
    
    # Scrape setiap berita
    news_data = []
    for url in news_urls:
        print(f"Memproses: {url}")
        data = scrape_detik(url)
        if data:
            news_data.append(data)
    
    # Simpan ke CSV
    if news_data:
        df = pd.DataFrame(news_data)
        df.to_csv('detik_hukum.csv', index=False, quoting=csv.QUOTE_ALL, encoding='utf-8-sig')
        print("Data berhasil disimpan")
    else:
        print("Tidak ada data yang berhasil di-scrape")

if __name__ == "__main__":
    main()
# Out:
# Memproses: https://news.detik.com/berita/d-8043532/geger-penumpang-lion-air-marah-marah-dan-teriak-ada-bom
# Memproses: https://news.detik.com/internasional/d-8043515/menteri-israel-pimpin-ibadah-yahudi-di-masjid-al-aqsa-turki-meradang
# Memproses: https://news.detik.com/berita/d-8043525/6-fakta-pesawat-latih-jatuh-di-bogor-marsma-fajar-adriyanto-gugur
# Memproses: https://news.detik.com/berita/d-8043609/ganjar-ungkap-alasan-hasto-tak-ada-di-susunan-kepengurusan-pdip
# Memproses: https://news.detik.com/berita/d-8043543/ulah-wanita-tenteng-tas-hermes-malah-curi-berlian-di-mal
# Memproses: https://news.detik.com/berita/d-8044218/4-siswa-siram-air-keras-ke-pelajar-smk-di-jakut-jadi-tersangka
# Memproses: https://news.detik.com/berita/d-8044210/viral-pemotor-santai-melaju-di-tol-japek-ngaku-gegara-google-maps
# Memproses: https://news.detik.com/berita/d-8044202/potret-penumpang-teriak-bom-di-pesawat-lion-air-kini-berbaju-tahanan
# Memproses: https://news.detik.com/berita/d-8043910/langka-mk-diminta-batalkan-putusan-sendiri-soal-pemisahan-pemilu-pilkada
# Memproses: https://news.detik.com/berita/d-8043748/uu-kementerian-digugat-lagi-mk-diminta-larang-wamen-jabat-komisaris
# Memproses: https://news.detik.com/berita/d-8042333/bakamla-amankan-kapal-selundupkan-400-karung-bawang-merah-di-kepri
# Memproses: https://20.detik.com/detikupdate/20250802-250802181/video-megawati-kritik-hukum-di-ri-seolah-kita-bukan-warga-yang-sah
# Memproses: https://news.detik.com/berita/d-8042245/pelarian-8-bulan-duo-maling-bermobil-yang-incar-rumah-mewah-di-jaktim
# Memproses: https://news.detik.com/berita/d-8041817/megawati-kritik-hukum-di-indonesia-seolah-kita-bukan-warga-yang-sah
# Memproses: https://news.detik.com/berita/d-8041568/kakek-di-cilincing-tewas-tertimpa-dongkrak-yang-dilempar-bajilo-pelaku-dibekuk
# Memproses: https://news.detik.com/berita/d-8041206/kpk-amnesti-hasto-tak-berdampak-ke-pencarian-harun-masiku
# Memproses: https://news.detik.com/berita/d-8040938/2-maling-bermobil-ditangkap-polisi-jam-rolex-hingga-tas-lv-disita
# Memproses: https://news.detik.com/berita/d-8040909/menkum-sambangi-kejaksaan-agung-antar-keppres-abolisi-tom-lembong
# Memproses: https://news.detik.com/berita/d-8040679/duo-maling-bermobil-gasak-rumah-mewah-di-cibubur-harta-rp-2-m-raib
# Memproses: https://news.detik.com/berita/d-8040438/warga-malaysia-polisikan-istri-di-jaksel-ngaku-dianiaya-saat-minta-cerai
# Memproses: https://news.detik.com/berita/d-8039824/perjalanan-tom-lembong-divonis-4-5-tahun-penjara-hingga-dapat-abolisi
# Memproses: https://news.detik.com/berita/d-8039763/hasto-dapat-amnesti-dan-tom-lembong-abolisi-pn-jakpus-hormati-prabowo
# Memproses: https://news.detik.com/berita/d-8039726/legislator-pdip-apresiasi-amnesti-untuk-hasto-sikap-negarawan-prabowo
# Memproses: https://news.detik.com/berita/d-8039447/eks-pejabat-esdm-ditetapkan-jadi-tersangka-kasus-manipulasi-batu-bara
# Memproses: https://news.detik.com/berita/d-8039424/pihak-hasto-kristiyanto-sambut-baik-pemberian-amnesti-dari-prabowo
# Memproses: https://news.detik.com/berita/d-8039403/kejagung-soal-tom-lembong-dapat-abolisi-dari-prabowo-kami-pelajari-dulu
# Memproses: https://news.detik.com/berita/d-8039383/ketua-kpk-soal-hasto-dapat-amnesti-kewenangan-presiden-berdasar-uud
# Memproses: https://news.detik.com/berita/d-8039253/hasto-pdip-divonis-3-5-tahun-penjara-kpk-akan-ajukan-banding
# Memproses: https://news.detik.com/berita/d-8039159/kpk-tahan-2-tersangka-hasil-pengembangan-kasus-korupsi-pengadaan-lng
# Memproses: https://news.detik.com/berita/d-8039041/ruben-onsu-laporkan-akun-medsos-yang-bully-anaknya-polda-metro-selidiki
# Memproses: https://news.detik.com/berita/d-8038209/pejabat-perusahaan-sekuritas-dipanggil-kpk-di-kasus-investasi-fiktif-taspen
# Memproses: https://news.detik.com/berita/d-8037835/paspor-riza-chalid-dicabut-mau-lari-ke-mana-lagi
# Memproses: https://news.detik.com/berita/d-8036633/kubu-tom-lembong-sebut-hakim-bisa-bebaskan-terdakwa-korupsi-asal-sesuai-fakta
# Memproses: https://news.detik.com/berita/d-8036609/sby-negara-kuat-bisa-jatuh-karena-pemimpin-letakkan-diri-di-atas-hukum
# Memproses: https://news.detik.com/berita/d-8036299/melawan-vonis-tom-lembong-singgung-soal-ekonomi-kapitalis
# Memproses: https://news.detik.com/berita/d-8035644/riza-chalid-yang-masih-tak-ada-kabar-berita
# Memproses: https://news.detik.com/berita/d-8035534/kpk-beber-modus-korupsi-rugikan-negara-rp-80-m-proyek-fiktif-tapi-ada-invoice
# Memproses: https://news.detik.com/berita/d-8034729/eks-wamendes-ungkap-isi-gugatan-ke-roy-suryo-dkk-soal-isu-ijazah-palsu-jokowi
# Memproses: https://news.detik.com/berita/d-8033520/partai-buruh-gugat-uu-pemilu-ke-mk-minta-ambang-batas-dpr-dihitung-per-dapil
# Memproses: https://news.detik.com/berita/d-8033407/wa-mr-k-dibuka-di-sidang-eks-dirut-taspen-ngaku-serba-salah-menjawab
# Memproses: https://news.detik.com/berita/d-8033222/tuntut-7-tahun-bui-jaksa-ketua-pn-surabaya-terima-gratifikasi-rp-21-9-m
# Memproses: https://news.detik.com/berita/d-8032428/kpk-usut-aliran-duit-korupsi-pengadaan-iklan-bank-bjb-dari-perusahaan-agency
# Memproses: https://news.detik.com/berita/d-8032421/kasus-vonis-bebas-ronald-tannur-eks-ketua-pn-surabaya-dituntut-7-tahun-bui
# Memproses: https://news.detik.com/berita/d-8032383/mantan-buron-kelas-kakap-adelin-lis-gugat-uu-tipikor-ke-mk
# Memproses: https://news.detik.com/berita/d-8031032/sekuel-zarof-eks-pejabat-ma-vonis-diperberat-perkara-lain-menanti
# Memproses: https://news.detik.com/berita/d-8030604/anak-korban-pemerkosaan-ayah-kandung-di-bekasi-jalani-konseling
# Memproses: https://news.detik.com/berita/d-8030564/ayah-perkosa-anak-kandung-di-bekasi-ancam-dan-ambil-hp-korban
# Memproses: https://news.detik.com/berita/d-8030536/begini-siasat-bejat-ayah-di-bekasi-perkosa-anak-kandung-sampai-berkali-kali
# Memproses: https://news.detik.com/berita/d-8030490/ayah-pemerkosa-anak-di-serang-sempat-kabur-3-bulan-sembunyi-di-gubuk
# Memproses: https://news.detik.com/berita/d-8030295/alasan-hakim-naikkan-hukuman-zarof-ricar-jadi-18-tahun-bui
# Memproses: https://www.detik.com/tag/hut-ri
# Memproses: https://www.detik.com/tag/kecelakaan-pesawat
# Memproses: https://www.detik.com/tag/palestina
# Memproses: https://news.detik.com/berita/d-8044136/pria-ngamuk-teriak-bom-di-pesawat-lion-air-ditetapkan-jadi-tersangka
# Memproses: https://news.detik.com/berita/d-8044160/ketua-kpk-jawab-mega-soal-hasto-status-bersalah-melekat-tapi-diampuni
# Memproses: https://news.detik.com/internasional/d-8043990/kaget-lihat-sandera-kurus-kering-netanyahu-minta-bantuan-palang-merah
# Memproses: https://news.detik.com/berita/d-8044202/potret-penumpang-teriak-bom-di-pesawat-lion-air-kini-berbaju-tahanan
# Memproses: https://news.detik.com/bbc-world/d-8044031/gempar-suap-menteri-singapura-miliuner-ong-beng-seng-mengaku-bersalah
# Memproses: https://news.detik.com/berita/d-8039340/ini-pertimbangan-prabowo-beri-abolisi-ke-tom-lembong-dan-amnesti-untuk-hasto
# Memproses: https://news.detik.com/berita/d-8039289/prabowo-beri-abolisi-ke-tom-lembong-dan-amnesti-untuk-hasto
# Memproses: https://news.detik.com/berita/d-8032088/ribka-pdip-sebut-tanpa-kudatuli-tak-ada-presiden-tukang-kayu-ini-kata-projo
# Data berhasil disimpan

# %%
# List semua file CSV yang ingin digabungkan
file_paths = [
    'detik_berita.csv', 'detik_jabodetabek.csv', 'detik_internasional.csv', 'detik_hukum.csv'
]

# Membaca dan menggabungkan semua file
all_data = pd.concat((pd.read_csv(file) for file in file_paths), ignore_index=True)

# Menyimpan hasil gabungan ke file baru
all_data.to_csv('detik.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd
import ollama
from tqdm import tqdm

# %%
# Pilih model yang lebih ringan
MODEL_NAME = "phi3"

# Fungsi yang dioptimalkan
def generate_qa_light(text):
    prompt = f"""
    Buat 1 pertanyaan dan jawaban singkat (maks 20 kata) dari teks berikut:
    {text[:1000]}  # Lebih pendek untuk menghemat memori
    Format: Pertanyaan: <pertanyaan>\nJawaban: <jawaban>
    """
    
    try:
        response = ollama.generate(
            model=MODEL_NAME,
            prompt=prompt,
            options={
                "temperature": 0.3,  # Kurangi kreativitas untuk hasil lebih konsisten
                "num_ctx": 1024  # Batasi context window
            }
        )
        return response['response']
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
# Proses CSV dengan optimasi memori
def process_csv(input_path, output_path, sample_size=None):
    df = pd.read_csv(input_path)
    if sample_size:
        df = df.sample(min(sample_size, len(df)))
    
    results = []
    for _, row in tqdm(df.iterrows(), total=len(df)):
        generated = generate_qa_light(str(row['content']))
        if generated:
            try:
                q = generated.split("Pertanyaan: ")[1].split("\n")[0].strip()
                a = generated.split("Jawaban: ")[1].strip() if "Jawaban: " in generated else "-"
                results.append({
                    'content': row.get('content', ''),
                    'question': q,
                    'answer': a
                })
            except:
                continue
    
    pd.DataFrame(results).to_csv(output_path, index=False)

process_csv('detik.csv', 'detik_qa.csv')
# Out:
# 100%|██████████| 242/242 [6:14:14<00:00, 92.79s/it]
