# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import pandas as pd

# %%
def scrape_liputan6():
    url = "https://www.liputan6.com/tekno/berita"
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    
    try:
        # Request halaman indeks
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Cari semua link artikel
        articles = []
        article_elements = soup.find_all('a', href=True)
        
        for element in article_elements:
            href = element['href']
            if '/read/' in href and href not in articles:
                full_url = f"https://www.liputan6.com{href}" if not href.startswith('http') else href
                articles.append(full_url)
        
        print(f"Found {len(articles)} articles")
        
        # Scrape setiap artikel
        data = []
        for article_url in articles:
            print(f"Scraping: {article_url}")
            
            try:
                article_response = requests.get(article_url, headers=headers)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')
                
                # Ekstrak judul
                title = article_soup.find('h1')
                title = title.text.strip() if title else "No title"
                
                # Ekstrak konten
                content_div = article_soup.find('div', class_='article-content-body__item-content')
                if not content_div:
                    content_div = article_soup.find('div', class_='read-page--content')
                
                content = ""
                if content_div:
                    paragraphs = content_div.find_all('p')
                    content = ' '.join([p.text.strip() for p in paragraphs])
                
                data.append({
                    'title': title,
                    'url': article_url,
                    'content': content
                })
                
                time.sleep(3)  # Menghormati website
                
            except Exception as e:
                print(f"Error scraping {article_url}: {e}")
                continue
        
        # Simpan ke CSV
        with open('l6t_technews.csv', 'w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=['title', 'url', 'content'])
            writer.writeheader()
            writer.writerows(data)
        
    except Exception as e:
        print(f"Error: {e}")

# %%
if __name__ == "__main__":
    scrape_liputan6()
# Out:
# Found 82 articles
# Scraping: https://www.liputan6.com/tekno/read/6141666/apple-dan-google-jajaki-integrasi-gemini-untuk-otak-baru-siri
# Scraping: https://www.liputan6.com/tekno/read/6140904/tak-mau-kalah-dengan-apple-5-raksasa-hp-china-bersatu-perketat-sistem-keamanan-pengguna
# Scraping: https://www.liputan6.com/tekno/read/6136673/google-photos-bakal-bisa-bedakan-foto-asli-vs-buatan-ai-begini-cara-kerjanya
# Scraping: https://www.liputan6.com/tekno/read/6140303/hp-redmi-note-15-pro-dan-redmi-note-15-pro-plus-lolos-tkdn-siap-meluncur-di-indonesia
# Scraping: https://www.liputan6.com/tekno/read/6140153/harga-samsung-galaxy-a07-mulai-rp1-jutaan-dapat-update-os-hingga-6-tahun
# Scraping: https://www.liputan6.com/tekno/read/6139396/infinix-hot-60-pro-hadir-di-indonesia-hp-android-rp-2-jutaan-dengan-spesifikasi-gahar
# Scraping: https://www.liputan6.com/tekno/read/6139496/vivo-v60-meluncur-28-agustus-hadir-dengan-kamera-telephoto-pertama-di-seri-v
# Scraping: https://www.liputan6.com/tekno/read/6137809/spesifikasi-redmi-15c-punya-baterai-jumbo-6000mah-tapi-bodi-tetap-tipis
# Scraping: https://www.liputan6.com/tekno/read/6137074/oppo-find-x9-ultra-dan-galaxy-s26-ultra-disebut-pakai-sensor-kamera-sama
# Scraping: https://www.liputan6.com/tekno/read/6137777/redmi-15c-siap-hadir-di-indonesia-25-agustus-harga-mulai-rp-15-jutaan
# Scraping: https://www.liputan6.com/tekno/read/6136758/mengapa-sekarang-baterai-hp-lebih-cepat-rusak-ini-penyebabnya
# Scraping: https://www.liputan6.com/tekno/read/6138584/butuh-biaya-tinggi-openai-akan-tampilkan-iklan-di-chatgpt
# Scraping: https://www.liputan6.com/tekno/read/6138057/nasa-temukan-bulan-baru-di-uranus-ukurannya-sepertiga-kota-new-york
# Scraping: https://www.liputan6.com/tekno/read/6135398/fitur-always-on-display-iphone-kini-punya-efek-blur-bikin-tulisan-lebih-jelas
# Scraping: https://www.liputan6.com/tekno/read/6140227/top-3-tekno-vivo-v60-siap-rilis-di-indonesia-28-agustus-dengan-kamera-telefoto
# Scraping: https://www.liputan6.com/tekno/read/6138824/oppo-find-x9-pro-bakal-ditopang-kamera-200mp-dari-samsung-dan-sony
# Scraping: https://www.liputan6.com/tekno/read/6139834/apjii-soroti-wacana-internet-murah-hingga-moratorium-izin-isp
# Scraping: https://www.liputan6.com/tekno/read/6139700/jelang-iixs-2025-apjii-tekankan-hilirisasi-digital-dan-peran-ai-di-indonesia
# Scraping: https://www.liputan6.com/tekno/read/6137490/nasa-dan-google-uji-dokter-ai-untuk-obati-astronaut-di-luar-angkasa-bagaimana-cara-kerjanya
# Scraping: https://www.liputan6.com/tekno/read/6138777/bocoran-baru-samsung-galaxy-s25-fe-jadwal-rilis-resolusi-kamera-hingga-performa
# Scraping: https://www.liputan6.com/tekno/read/6139073/top-3-tekno-ios-26-beta-7-hingga-spesifikasi-redmi-15c
# Scraping: https://www.liputan6.com/tekno/read/6139066/riset-genai-berpotensi-perluas-penyebaran-misinformasi-hingga-ancaman-privasi
# Scraping: https://www.liputan6.com/tekno/read/6138871/telkomsel-dan-openai-teken-mou-di-solution-day-2025-siap-bawa-ai-inklusif-ke-indonesia
# Scraping: https://www.liputan6.com/tekno/read/6137707/pengguna-instagram-reels-bisa-dubbing-bahasa-asing-dengan-meta-ai-translation-begini-caranya
# Scraping: https://www.liputan6.com/tekno/read/6138817/transaksi-tokopedia-naik-127-persen-pada-juli-2024-juni-2025-apa-produk-paling-laris
# Scraping: https://www.liputan6.com/tekno/read/6137020/google-bangun-pusat-nuklir-pertama-untuk-data-center
# Scraping: https://www.liputan6.com/tekno/read/6137468/diprotes-karyawan-microsoft-selidiki-kontrak-perusahaan-dengan-israel
# Scraping: https://www.liputan6.com/tekno/read/6138305/top-3-tekno-redmi-15c-di-indonesia-hingga-harga-iphone-16-dan-16-pro-max-turun-harga
# Scraping: https://www.liputan6.com/tekno/read/6136976/ios-26-beta-7-dirilis-pemolesan-akhir-sebelum-versi-final
# Scraping: https://www.liputan6.com/tekno/read/6138079/pixel-10-resmi-diumumkan-di-made-by-google-2025-cek-spesifikasi-dan-harganya
# Scraping: https://www.liputan6.com/tekno/read/6137381/apple-bakal-hapus-camera-control-dari-iphone-18-benarkah
# Scraping: https://www.liputan6.com/tekno/read/6135823/selain-halusinasi-ai-apa-benar-kecerdasan-buatan-bisa-bikin-orang-kena-psikosis
# Scraping: https://www.liputan6.com/tekno/read/6137685/iphone-16-dan-16-pro-max-turun-harga-di-agustus-2025-hingga-rp-4-juta-cek-daftar-terbarunya
# Scraping: https://www.liputan6.com/tekno/read/6137489/mengenal-seamless-go-subscription-service-platform-langganan-multi-kategori-elektronik-rumah-tangga-dari-modena
# Scraping: https://www.liputan6.com/tekno/read/6136836/bocoran-spesifikasi-galaxy-s26-pro-terungkap-apa-yang-beda-dari-generasi-sebelumnya
# Scraping: https://www.liputan6.com/tekno/read/6137026/top-3-tekno-tanggal-rilis-redmi-note-15-pro-hingga-spesifikasi-iphone-17e
# Scraping: https://www.liputan6.com/tekno/read/6135626/ios-26-hadirkan-4-fitur-safari-tersembunyi-apa-saja
# Scraping: https://www.liputan6.com/tekno/read/6136573/bocoran-harga-xiaomi-15t-series-punya-kamera-50mp-dan-baterai-jumbo-5500-mah
# Scraping: https://www.liputan6.com/tekno/read/6135812/smart-glass-baru-meta-hypernova-siap-rilis-lebih-murah-dari-prediksi-awal
# Scraping: https://www.liputan6.com/tekno/read/6131686/pendapatan-sea-group-meroket-shopee-dan-garena-jadi-tulang-punggung
# Scraping: https://www.liputan6.com/tekno/read/6136516/bocoran-spesifikasi-iphone-17e-mulai-terkuak-apa-lagi-yang-baru
# Scraping: https://www.liputan6.com/tekno/read/6135678/hp-redmi-note-15-pro-muncul-di-geekbench-bakal-debut-pakai-snapdragon-7s-gen-4
# Scraping: https://www.liputan6.com/tekno/read/6136210/top-3-tekno-4-miliarder-yang-kaya-raya-berkat-ai-tuai-perhatian
# Scraping: https://www.liputan6.com/tekno/read/6135088/oppo-a6-pro-5g-pakai-dimensity-6300-sama-seperti-pendahulu-tapi-kecepatan-isi-daya-melonjak
# Scraping: https://www.liputan6.com/tekno/read/6135549/chip-m5-debut-di-ipad-pro-musim-gugur-macbook-pro-menyusul-2026
# Scraping: https://www.liputan6.com/tekno/read/6135487/xiaomi-umumkan-tanggal-rilis-redmi-note-15-pro-kapan
# Scraping: https://www.liputan6.com/tekno/read/6135920/kemkomdigi-bawa-truk-digital-di-karnaval-hut-ri-ke-80-ada-robot-ai-hingga-satelit-satria-1
# Scraping: https://www.liputan6.com/tekno/read/6133520/xiaomi-hyperos-3-siap-rilis-intip-fitur-baru-dari-update-berbasis-android-16
# Scraping: https://www.liputan6.com/tekno/read/6135461/infinix-hot-60-pro-rilis-20-agustus-di-indonesia-intip-spesifikasi-hp-android-bodi-tipis
# Scraping: https://www.liputan6.com/tekno/read/6132927/mediatek-dimensity-9500-rilis-22-september-2025-dahului-snapdragon-8-elite-2
# Scraping: https://www.liputan6.com/tekno/read/6135175/top-3-tekno-telkomsel-sebar-promo-hut-ri-ke-80-hingga-galaxy-s25-fe-tembus-tkdn
# Scraping: https://www.liputan6.com/tekno/read/6131780/china-panggil-sederet-perusahaan-teknologi-yang-beli-chip-ai-nvidia
# Scraping: https://www.liputan6.com/tekno/read/6130345/teknologi-ai-lahirkan-4-miliarder-baru-siapa-paling-kaya
# Scraping: https://www.liputan6.com/tekno/read/6129744/7-settingan-hp-android-agar-lebih-awet-dan-bebas-dari-hacker
# Scraping: https://www.liputan6.com/tekno/read/6129507/teknologi-3d-printing-dan-ai-percepat-konstruksi-nuklir-inovasi-atau-ancaman
# Scraping: https://www.liputan6.com/tekno/read/6132118/cek-deretan-upgrade-besar-gpt-5-apa-saja
# Scraping: https://www.liputan6.com/tekno/read/6132466/ini-spesifikasi-poco-m7-4g-yang-punya-baterai-jumbo-7000-mah
# Scraping: https://www.liputan6.com/tekno/read/6134218/apa-itu-samsung-knox-ini-deretan-fitur-canggih-untuk-lindungi-data-pribadi-dan-perusahaan
# Scraping: https://www.liputan6.com/tekno/read/6130532/samsung-suntik-rp-110-triliun-untuk-pabrik-chip-di-as
# Scraping: https://www.liputan6.com/tekno/read/6132767/samsung-luncurkan-kacamata-pintar-tanpa-ar-fokus-ke-fitur-praktis
# Scraping: https://www.liputan6.com/tekno/read/6133851/ini-pilihan-warna-dan-spesifikasi-vivo-v60-di-indonesia
# Scraping: https://www.liputan6.com/tekno/read/6133804/whatsapp-tuding-balik-rusia-terkait-pembatasan-fitur-voice-call
# Scraping: https://www.liputan6.com/tekno/read/6133549/hemat-dan-ramah-lingkungan-skema-berlangganan-elektronik-rumah-tangga-jadi-tren-di-kalangan-gen-z
# Scraping: https://www.liputan6.com/tekno/read/6133496/merdeka-dari-spam-dan-scam-tri-hadirkan-perlindungan-digital-berbasis-ai
# Scraping: https://www.liputan6.com/tekno/read/6125408/elevenlabs-rilis-ai-pembuat-musik-legal-bisa-dipakai-untuk-youtube-hingga-iklan
# Scraping: https://www.liputan6.com/tekno/read/6133408/prabowo-teknologi-bukan-cuma-modernisasi-tapi-juga-untuk-tingkatkan-transparansi-pemerintahan
# Scraping: https://www.liputan6.com/tekno/read/6131543/roblox-punya-fitur-ai-anti-chat-toxic-untuk-lindungi-anak-dari-pelecehan
# Scraping: https://www.liputan6.com/tekno/read/6133202/top-3-tekno-rusia-batasi-whatsapp-call-hingga-harga-iphone-17-pro-bakal-naik
# Scraping: https://www.liputan6.com/tekno/read/6131550/hapus-objek-foto-dengan-generative-edit-di-galaxy-z-fold7-lebih-cerdas-dan-satset-begini-hasilnya?HouseAds&campaign=TipsTekno_Tekno_STS2
# Scraping: https://www.liputan6.com/tekno/read/6125389/ini-penyebab-gagal-top-up-gopay-dan-cara-mengatasinya?HouseAds&campaign=TipsTekno_Tekno_STS2
# Scraping: https://www.liputan6.com/tekno/read/6118337/cara-mudah-dan-murah-update-driver-nvidia-di-pc-atau-laptop-agar-gaming-makin-ngebut?HouseAds&campaign=TipsTekno_Tekno_STS2
# Scraping: https://www.liputan6.com/tekno/read/6139726/whatsapp-call-bakal-kedatangan-fitur-voicemail-untuk-panggilan-tak-terjawab?HouseAds&campaign=Android_Tekno_STS1
# Scraping: https://www.liputan6.com/tekno/read/6139396/infinix-hot-60-pro-hadir-di-indonesia-hp-android-rp-2-jutaan-dengan-spesifikasi-gahar?HouseAds&campaign=Android_Tekno_STS1
# Scraping: https://www.liputan6.com/tekno/read/6130487/update-google-system-di-android-resmi-rilis-apa-saja-fitur-barunya?HouseAds&campaign=Android_Tekno_STS1
# Scraping: https://www.liputan6.com/tekno/read/6139726/whatsapp-call-bakal-kedatangan-fitur-voicemail-untuk-panggilan-tak-terjawab
# Scraping: https://www.liputan6.com/tekno/read/6141179/top-3-tekno-hp-redmi-note-15-pro-series-tembus-tkdn-hingga-jadwal-mpl-id-s16
# Scraping: https://www.liputan6.com/tekno/read/6140850/nggak-perlu-panik-ini-4-jurus-sakti-jagain-amp-balikin-saldo-digital-kamu
# Scraping: https://www.liputan6.com/tekno/read/6140762/realme-pamer-ponsel-dengan-baterai-12000mah-tiga-kali-lipat-iphone-16
# Scraping: https://www.liputan6.com/tekno/read/6139610/china-batasi-pembelian-chip-ai-nvidia-gara-gara-komentar-negatif-pejabat-as-howard-lutnick
# Scraping: https://www.liputan6.com/tekno/read/6141546/samsung-galaxy-a07-resmi-meluncur-di-indonesia-harga-mulai-rp-1-jutaan
# Scraping: https://www.liputan6.com/tekno/read/6141417/direktur-scm-berbagi-tips-kelola-konten-agar-sukses-di-berbagai-platform-saat-hadiri-raker-imde
# Scraping: https://www.liputan6.com/tekno/read/6141138/rog-xbox-ally-segera-rilis-di-indonesia-ini-spesifikasi-dan-fitur-unggulannya

# %%
# List semua file CSV yang ingin digabungkan
file_paths = [
    'l6t_gadget.csv', 'l6t_internet.csv', 'l6t_games.csv', 'l6t_apps.csv', 'l6t_technews.csv', 'l6t_tips.csv'
]

# Membaca dan menggabungkan semua file
all_data = pd.concat((pd.read_csv(file) for file in file_paths), ignore_index=True)

# Menyimpan hasil gabungan ke file baru
all_data.to_csv('l6_teknologi.csv', index=False, encoding='utf-8-sig')
